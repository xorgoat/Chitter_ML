# %% [markdown]
# # Pre-processing

# %% [markdown]
# Mounting Drive and Importing Data

# %%
#Add the folder I shared with you guys to your drive then run this code block
from google.colab import drive
drive.mount('/gdrive')
# !ln -s "/gdrive/My Drive/SE" "/content/SE"
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# ln: failed to create symbolic link '/content/SE/SE': Operation not supported

# %%
#import the data
import pandas as pd
import numpy as np
import os
birds_images = pd.read_csv("/content/SE/birds/birds.csv")

# %%
#selecting an image and outputting it
import matplotlib.pyplot as plt
from PIL import Image
img = Image.open('/content/SE/birds/test/AFRICAN CROWNED CRANE/2.jpg')
plt.imshow(img)

# %% [markdown]
# Original Bird Image Data Distribution

# %%
'''#Storing the names and amount of each species in the dataset
path = "/content/SE/birds/train/"
lst = os.listdir(path) 
bird_diff_species = {}  #creating a dictionary
bird_species_amount = len(lst) #might be with .ipynb checkpoints added so watch out!
print("number of bird species:", bird_species_amount)

for birds in lst:
  bird_species_source = os.path.join(path, birds)
  n_birds_in_species = len(os.listdir(bird_species_source))
  """print(bird_species_source)"""
  bird_diff_species.update({str(birds): n_birds_in_species})  #storing the species' names and how much of each there are in the data set

print(bird_diff_species)

bird_keys = bird_diff_species.keys()
bird_values = bird_diff_species.values() '''

# %%
#making a graph of all the species and how many there are of each in the dataset
#output is currently cleared to save room. See the shared Google Drive folder for the output
"""plt.figure(figsize=(10,40), dpi=200)

plt.barh(list(bird_keys), bird_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/birds/bird_data_distribution.jpg") #name and path pf the output file
plt.show()
"""
#no need to run again as the file is already saved

# %% [markdown]
# Getting the Insect Class Names

# %%
'''pip install pygbif'''

# %%
import csv
'''
from pygbif import occurrences as occ


path = "/content/SE/Bugs/"


with open('/content/SE/bugs.csv', 'w') as file:
    writer = csv.writer(file)
    bugs_header = ['id', 'species', 'nl']
    writer.writerow(bugs_header)

with open('/content/SE/error_bugs.csv', 'w') as file:
    writer = csv.writer(file)
    bugs_header = ['id']
    writer.writerow(bugs_header)

lst = os.listdir(path) #listing different bug species
bug_diff_species = {} #dictionary of amount of files per bug species
bug_species_amount = len(lst) #amount of bug species, might be with .ipynb checkpoints added so watch out!
print("number of bug species:", bug_species_amount)

for bugs in lst:
  if bugs == ".ipynb_checkpoints":
    continue;
  gbif_id = str(bugs) #id number of the current species
  bug_species_source = os.path.join(path, gbif_id)

  try:
    results = occ.search(taxonKey = gbif_id)
  except:
    print("Something went wrong with pulling the results from the web database for id ", gbif_id)
    with open('/content/SE/error_bugs.csv', 'a') as file:
      writer = csv.writer(file)
      data = [gbif_id]
      writer.writerow(data)

  try:
    species_name = results['results'][0]['species']
    
    country = {'Netherlands':'no'}

    for c in results['results']:
      observed_country = c['country']
      if observed_country == 'Netherlands':
        country['Netherlands'] = 'yes'
        break;

    with open('/content/SE/bugs.csv', 'a') as file: #append to our growing csv file
        writer = csv.writer(file)
        bugs_data = [gbif_id, species_name, country['Netherlands']]
        writer.writerow(bugs_data)

  except:
    print(f"Something went wrong with bug {gbif_id}")
    with open('/content/SE/error_bugs.csv', 'a') as file:
      writer = csv.writer(file)
      data = [gbif_id]
      writer.writerow(data)

  n_bugs_in_species = len(os.listdir(bug_species_source))
  bug_diff_species.update({species_name: n_bugs_in_species})  #storing the species' names and how much of each there are in the data set

print(bug_diff_species)


bug_keys = bug_diff_species.keys()
bug_values = bug_diff_species.values()

'''
#no need to run again as it takes 7+ mins and the file is already saved
# Out:
# '\nfrom pygbif import occurrences as occ\n\n\npath = "/content/SE/Bugs/"\n\n\nwith open(\'/content/SE/bugs.csv\', \'w\') as file:\n    writer = csv.writer(file)\n    bugs_header = [\'id\', \'species\', \'nl\']\n    writer.writerow(bugs_header)\n\nwith open(\'/content/SE/error_bugs.csv\', \'w\') as file:\n    writer = csv.writer(file)\n    bugs_header = [\'id\']\n    writer.writerow(bugs_header)\n\nlst = os.listdir(path) #listing different bug species\nbug_diff_species = {} #dictionary of amount of files per bug species\nbug_species_amount = len(lst) #amount of bug species, might be with .ipynb checkpoints added so watch out!\nprint("number of bug species:", bug_species_amount)\n\nfor bugs in lst:\n  if bugs == ".ipynb_checkpoints":\n    continue;\n  gbif_id = str(bugs) #id number of the current species\n  bug_species_source = os.path.join(path, gbif_id)\n\n  try:\n    results = occ.search(taxonKey = gbif_id)\n  except:\n    print("Something went wrong with pulling the results from the web database for id ", gbif_id)\n    with open(\'/content/SE/error_bugs.csv\', \'a\') as file:\n      writer = csv.writer(file)\n      data = [gbif_id]\n      writer.writerow(data)\n\n  try:\n    species_name = results[\'results\'][0][\'species\']\n    \n    country = {\'Netherlands\':\'no\'}\n\n    for c in results[\'results\']:\n      observed_country = c[\'country\']\n      if observed_country == \'Netherlands\':\n        country[\'Netherlands\'] = \'yes\'\n        break;\n\n    with open(\'/content/SE/bugs.csv\', \'a\') as file: #append to our growing csv file\n        writer = csv.writer(file)\n        bugs_data = [gbif_id, species_name, country[\'Netherlands\']]\n        writer.writerow(bugs_data)\n\n  except:\n    print(f"Something went wrong with bug {gbif_id}")\n    with open(\'/content/SE/error_bugs.csv\', \'a\') as file:\n      writer = csv.writer(file)\n      data = [gbif_id]\n      writer.writerow(data)\n\n  n_bugs_in_species = len(os.listdir(bug_species_source))\n  bug_diff_species.update({species_name: n_bugs_in_species})  #storing the species\' names and how much of each there are in the data set\n\nprint(bug_diff_species)\n\n\nbug_keys = bug_diff_species.keys()\nbug_values = bug_diff_species.values()\n\n'

# %%
#all of the insects in error_bugs exist on the gbif website, but have 
#no or differing data in the database 
"""bug_prison = []
truly_corrupt_bugs = []

with open ('/content/SE/error_bugs.csv', 'r') as file:
  for bad_bug in file:
    less_bad_bug = bad_bug.replace('\n', '')
    bug_prison.append(less_bad_bug)
  bug_prison.remove('id')

for inmate in bug_prison:
  try:
    results = occ.search(taxonKey = inmate)
    species_name = results['results'][0]['species']
    print(species_name, results['results'][0]['countryCode'])
  except:
    truly_corrupt_bugs.append(inmate)

print(len(truly_corrupt_bugs)) """

#these insects have no name in database or are not in NL

# %% [markdown]
# Original Insect Image Data Distribution

# %%
"""
plt.figure(figsize=(10,40), dpi=200)

plt.barh(list(bug_keys), bug_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/bug_data_distribution.jpg")
"""

#no need to run again, already have the file saved

# %% [markdown]
# Narrowing the Bird Image Dataset (location filter)

# %%
#crossreferencing the bird dataset species with species that appear in the netherlands 
"""
birds = pd.read_csv("/content/SE/birds/birds latin names.csv")
birds_nl = pd.read_csv("/content/SE/birds/birds_nl.csv")

with open('/content/SE/birds/overlap_nl.csv', 'w') as file:
    writer = csv.writer(file)
    header = ['index', 'scientific', 'common']
    writer.writerow(header)

    for index_nl, row_nl in birds_nl.iterrows(): #nl species
      for index, row in birds.iterrows(): #dataset species
        if row['SCIENTIFIC NAME'].lower() == row_nl['latin names'].lower(): #if scientific name matches nl one
        new_row = [index, row_nl['latin names'], row['class']] #index is the class index within bird.csv to collect the files later
          writer.writerow(new_row)
"""
#file is already saved, no need to run again
#using scientific names is better than using common names as these are inconsistent (and thus unreliable to compare against)

# %%
#continuation of last code block: copying the files to new folders for easy 
#identification of test, train, and validation files

import shutil
"""
new = pd.read_csv("/content/SE/birds/overlap_nl.csv")

for index, row in new.iterrows():
  old_file_path_train = "/content/SE/birds/train/" + row['common']
  new_file_path_train = "/content/SE/birds/train_nl/" + row['common']
  shutil.copytree(old_file_path_train, new_file_path_train)

  old_file_path_test = "/content/SE/birds/test/" + row['common']
  new_file_path_test = "/content/SE/birds/test_nl/" + row['common']
  shutil.copytree(old_file_path_test, new_file_path_test)

  old_file_path_valid = "/content/SE/birds/valid/" + row['common']
  new_file_path_valid = "/content/SE/birds/valid_nl/" + row['common']
  shutil.copytree(old_file_path_valid, new_file_path_valid)
  
#!cp old_file_path new_file_path --> this does not work as it combined python variable and linux command 
"""
#no need to uncomment, already copied all files
# Out:
# '\nnew = pd.read_csv("/content/SE/birds/overlap_nl.csv")\n\nfor index, row in new.iterrows():\n  old_file_path_train = "/content/SE/birds/train/" + row[\'common\']\n  new_file_path_train = "/content/SE/birds/train_nl/" + row[\'common\']\n  shutil.copytree(old_file_path_train, new_file_path_train)\n\n  old_file_path_test = "/content/SE/birds/test/" + row[\'common\']\n  new_file_path_test = "/content/SE/birds/test_nl/" + row[\'common\']\n  shutil.copytree(old_file_path_test, new_file_path_test)\n\n  old_file_path_valid = "/content/SE/birds/valid/" + row[\'common\']\n  new_file_path_valid = "/content/SE/birds/valid_nl/" + row[\'common\']\n  shutil.copytree(old_file_path_valid, new_file_path_valid)\n  \n#!cp old_file_path new_file_path --> this does not work as it combined python variable and linux command \n'

# %% [markdown]
# Narrowing the Bird Audio Dataset (location filter)

# %%
#We need to go through the xcmeta.csv (SE/bird_recordings/xcmeta.csv)
#Column bird_recordings[5] (‘cnt’) has which countries the bird recordings were taken in
#We find all instances of ‘Netherlands’
#see what the species (common) name is (bird_recordings[3], (‘en’)),
#then take all the recording from that species, 
#cross reference their id names (bird_recordings[0], (‘id’)) with the names of the recordings (“SE/bird_recordings/flac/”+id). 

'''
bird_sounds = pd.read_csv("/content/SE/bird_recordings/xcmeta.csv", sep="\\t")

with open("/content/SE/bird_recordings/xcmeta_nl.csv", 'w') as file: #as a redundancy, save all info on just nl birds in separate csv
    writer = csv.writer(file)		
    header = ['id','filename','scientific','common','country','type'] #copying only useful header names
    writer.writerow(header)
          
    #need to make sure we move all species even if observed in netherlands only once
    species_in_nl = {}
    for index, row in bird_sounds.iterrows():
      current_species = row['en']
      if species_in_nl.get(current_species) == "yes": #if species already determined to be in netherlands, just continue to next file
        writer.writerow([row['id'],("xc"+str(row['id'])+".flac"), (row['gen']+" "+row['sp']),row['en'], row['cnt'],row['type']]) #put current file into csv
        continue
      elif row['cnt'] == 'Netherlands': #if species not yet catalogued as nl but appears in nl
        species_in_nl[current_species] = "yes"
        writer.writerow([row['id'],("xc"+str(row['id'])+".flac"), (row['gen']+" "+row['sp']),row['en'], row['cnt'],row['type']]) #put current file into csv
      else: #put in as not appearing in nl as of now
        species_in_nl[current_species] = "no"

'''

#already saved

# %%
#We then move those files into a folder SE/bird_recordings/bird_rec_nl  (or smth else)
'''
bird_sounds_nl = pd.read_csv("/content/SE/bird_recordings/xcmeta_nl.csv")
path = "/content/SE/bird_recordings/flac/"

bird_recordings = os.listdir(path)
ids_with_no_recording = [] #for the files in the csv that have no audio file match

#for all nl id's, check if overlaps with bird id of recording dataset
for index, row in bird_sounds_nl.iterrows(): 
  current_id = row['id']
  file_name_to_move = row['filename'] #file name associated with id
  old_path = "/content/SE/bird_recordings/flac/" + file_name_to_move
  new_path = "/content/SE/bird_recordings/flac_nl/"+ row['common'] + "/" + file_name_to_move
  try:
    shutil.copyfile(old_path, new_path)
  except:
    folder = "/content/SE/bird_recordings/flac_nl/"+ row['common']
    if os.path.isfile(old_path) == False: #if there exists no file associated with the id
      ids_with_no_recording.append(current_id)
      continue
    elif os.path.isfile(folder) == False: #if the species folder doesnt exist yet
      os.makedirs(folder) #make one
      try: #try again to copy
        shutil.copyfile(old_path, new_path) 
      except:
        print("Something else is wrong with", current_id)

print(ids_with_no_recording)
'''
# Out:
# [35068, 152480, 95574, 25941, 113082, 65141, 114614, 78406, 128853, 121971, 121972, 121973, 121974, 121975, 101371, 109700, 96265, 25591, 168369, 167603, 113364, 72727, 72728, 131609, 29055, 127773, 169884, 78495, 169825, 83940, 109629, 131693, 26959, 28530, 131892, 131652, 42203, 135261, 30614, 42681, 133917, 133918, 142431, 175980, 183982, 33395, 179518, 75459, 83705, 70717, 91091, 90364, 139551, 92945, 152597, 166678, 148920, 148921, 181757, 181758, 97766, 184457, 100882, 44719, 100624, 164146, 167721, 111191, 35211, 138253, 138831, 138103, 78136, 25082, 43582, 114314, 42541, 42542, 175024, 171445, 25558, 100831, 66132, 95381, 176233, 94584, 181369, 176435, 176476, 35578, 176479, 99462, 111559, 111560, 125322, 53807, 92473, 88826, 27706, 27166, 164607, 101103, 72768, 72769, 99141, 164928, 164919, 72767, 72764, 72765, 72766, 75167, 92264, 42690, 121677, 113783, 144228, 28985, 89994, 77425, 53812, 77429, 82971, 190176, 96133, 145543, 145544, 82955, 147235, 181288, 26033, 155197, 133822, 155713, 43586, 28238, 30159, 96464, 99927, 161758, 98400, 71014, 145642, 70252, 70253, 70254, 184052, 177399, 180985, 72770, 102851, 102852, 66286, 66287, 164592, 66289, 72771, 119510, 63085, 104624, 48465, 133325, 36047, 31059, 168651, 189837, 71022, 130639, 36018, 183443, 133876, 36597, 28533, 99929, 36826, 29023, 71023, 37445, 133877, 89530, 46223, 72726, 59768, 29465, 144763, 184060, 32381, 42878, 142908, 56260, 44641, 137500, 182634, 182133, 48060, 139421, 139423, 96346, 179826, 133468, 133054, 133471, 132429, 26478, 30127, 30128, 145143, 139161, 98906, 163388, 126637, 120182, 29048, 92474, 158453, 99881, 33718, 170744, 146811, 101370, 123812, 123807, 122563, 127438, 112888, 175953, 88051, 141014, 183831, 89561, 89562, 161961, 33359, 33720, 110738, 110739, 48185, 178360, 178361, 35411, 90633, 167725, 44590, 178705, 134233, 40218, 100763, 111158, 103504, 103505, 64758, 64759, 138265, 83932, 46110, 138271, 152251, 161383, 162536, 121230, 44691, 44660, 106838, 40155, 151388, 98948, 89419, 89420, 30130, 156628, 156629, 156630, 98777, 26650, 115708, 151365, 39394, 147917, 175856, 40564, 62901, 152276, 152253, 98433, 97611, 177353, 26635, 153805, 97486, 23983, 42446, 177355, 23982, 54504, 42551, 145675, 133900, 133901, 40182, 133879, 133944, 130588, 37502, 126633, 130702, 91185, 70130, 130583, 44721, 164926, 81955, 84050, 25555, 181147, 140572, 137981, 100766, 37599, 26599, 106637, 34132, 180183, 82555, 103583, 171034, 144862, 49814, 106913, 53830, 108006, 37485, 180813, 37492, 180821, 142452, 143034, 106908, 187357, 35194, 150943, 112875, 143446, 186611, 186551, 75115, 186612, 186552, 143443, 143444, 143445, 17270, 186647, 186648, 186649, 25594, 44637, 44638, 186613, 97982, 69855]

# %%
'''
print("nr of bird ids:", len(pd.read_csv("/content/SE/bird_recordings/xcmeta.csv", sep="\\t")))
print("nr of bird audio files:", len(os.listdir("/content/SE/bird_recordings/flac")))

#print(f"\nnr of dutch bird ids that have no attached audio file: {len(ids_with_no_recording)} \n")

print("nr of dutch bird ids:", len(pd.read_csv("/content/SE/bird_recordings/xcmeta_nl.csv")))

species = os.listdir("/content/SE/bird_recordings/flac_nl")
total_count = 0
for birds in species:
  total_count += len(os.listdir("/content/SE/bird_recordings/flac_nl/"+birds))
print("nr of dutch bird audio files:", total_count)
'''
#nr of bird ids: 4619
#nr of bird audio files: 4131
#nr of dutch bird ids that have no attached audio file: 11
#nr of dutch bird ids: 360
#nr of dutch bird audio files: 349
#56 dutch bird species

# %%
#checking if there is a duplicate of id numbers in xcmeta.csv that could explain
#the difference in dutch bird ids vs dutch bird audio
'''
bird_sounds = pd.read_csv("/content/SE/bird_recordings/xcmeta.csv", sep="\\t")
id_amount = {}
for index, row in bird_sounds.iterrows():
  id = row['id']
  if id_amount.get(id):
    counter = id_amount[id]
    id_amount[id] = counter+1
  else:
    id_amount[id] = 1

print(max(id_amount.values()))

key2 = max(id_amount, key = lambda k: id_amount[k])
print(id_amount[key2])
'''
#no, there are just no audio files that exist for these (11) ids

# %% [markdown]
# Narrowing the Insect Image Dataset (location filter)

# %%
#because the Bugs folder is very unorganized, going to put
#the NL bugs into SE/bug_img_nl
#and change the folder names from their id into species name
'''
bug_nl_list = pd.read_csv("/content/SE/bugs.csv")
img_path = "/content/SE/Bugs/"
img_nl_path = "/content/SE/bug_img_nl/"

bug_img = os.listdir(img_path)

#for all nl id's, check if overlaps with an img id 
for index, row in bug_nl_list.iterrows(): 
  current_id = row['id']
  species = row['species']

  if row['nl'] == 'no': #skip bug if not in nl
    print("->", species, "is not in NL: skipped")
    continue 

  folder_to_move = img_path + str(current_id) + '/' #file name associated with id
  new_path = img_nl_path + str(species)
  print("-> Going through", current_id, species)

  exist = os.path.isdir(new_path)
  if exist == False:
    try:
      shutil.copytree(folder_to_move, new_path)
      print("Copied files")
    except:
      print("  ! Something went wrong with", current_id, species)
  else:
    print("Folder already exists for", current_id, species)
'''

# %% [markdown]
# Narrowing the Insect Audio Dataset (location filter)

# %%
#Names of bugs are written as a whole, without spaces, usually followed by either an underscore or a number. 
#After that comes the shortened scientific name, and then possibly the location. 
#This formatting is not consistent over all the files, but the no-space scientific name at the start does appear within all the audio file names.
#Ex.: Brevisianabrevis_MHV%20959%20B.brevis%20Morningside%20Ranch%20%232.wav
#Scientific name: Brevisiana brevis (B. brevis)
#Location recorded: Morningside Ranch

'''
old_test = "/content/SE/insectsound/ManualTest"
old_train = "/content/SE/insectsound/ManualTrain"
old_val = "/content/SE/insectsound/ManualValidation"

#make list of bugs in nl, with names that can be compared to the audio file names
bug_nl_list = pd.read_csv("/content/SE/bugs.csv")
unspaced_nl_species = []
for index, row in bug_nl_list.iterrows(): 
  country = row['nl']
  if country == "yes":
    species_name = row['species'].lower()
    species_name = species_name.replace(" ", "") #remove spaces from name
    unspaced_nl_species.append(species_name)
print (unspaced_nl_species)

#test folder
deletethisafter = []
lst = os.listdir(old_test)
for bug_sound in lst:
  species_name_raw = bug_sound.partition("_")[0].lower()
  species_name_raw = ''.join(filter(lambda x: not x.isdigit(), species_name_raw)) #remove digits from name
  if "species_name_raw" in unspaced_nl_species:
    print(bug_sound, "in nl")
  
  #print(species_name_raw)
  deletethisafter.append(species_name_raw)
print(deletethisafter)
  
  #test
  #for bug in unspaced_nl_species:
    #if "amaraan" in bug:
      #print(bug)
'''

#it seems like none of our audio bugs are in the nl, so we can just use the original file paths
# Out:
# ['amaraanthobia', 'loricerapilicornis', 'nebriabrevicollis', 'elaphrusriparius', 'bradycellusharpalinus', 'amaraapricaria', 'amarabifrons', 'bembidionproperans', 'bembidionbruxellense', 'bembidiontestaceum', 'bembidionlampros', 'bembidionobtusum', 'bembidiontetracolum', 'bembidionsemipunctatum', 'bembidionguttula', 'bembidionquadrimaculatum', 'carabusgranulatus', 'clivinafossor', 'asaphidionflavipes', 'clivinacollaris', 'acupalpusmeridianus', 'tachysscutellaris', 'trechusobtusus', 'anisodactylusbinotatus', 'bembidionminimum', 'dicheirotrichusgustavii', 'bembidioniricolor', 'bembidionaeneum', 'bembidionephippium', 'dicheirotrichusobsoletus', 'bembidionfumigatum', 'panagaeusbipustulatus', 'carabusproblematicus', 'anisodactyluspoeciloides', 'carabusnitens', 'masoreuswetterhallii', 'carabusviolaceus', 'carabusclatratus', 'broscuscephalotes', 'carabusmonilis', 'amaracommunis', 'amaralucida', 'amarasimilata', 'amaraconvexior', 'amaraeurynota', 'amaraspreta', 'amaraplebeja', 'panagaeuscruxmajor', 'amarainfima', 'amaraconsularis', 'leistusfulvibarbis', 'elaphrusuliginosus', 'stomispumicatus', 'leistusferrugineus', 'nebriasalina', 'elaphruscupreus', 'zabrustenebrioides', 'synuchusvivalis', 'olisthopusrotundatus', 'oxypselaphusobscurus', 'odacanthamelanura', 'paranchusalbipes', 'brachinuscrepitans', 'leistusspinibarbis', 'leistusterminatus', 'ophonusrufibarbis', 'ophonusrupicola', 'ophonusmelletii', 'ophonusardosiacus', 'ophonuslaticollis', 'ophonuspuncticeps', 'ophonuscordatus', 'acupalpusdubius', 'acupalpusbrunnipes', 'dicheirotrichusplacidus', 'anthracusconsputus', 'trechoblemusmicros', 'trechusquadristriatus', 'patrobusatrorufus', 'acupalpusexiguus', 'asaphidionstierlini', 'blemusdiscus', 'asaphidioncurtum', 'bembidionquadripustulatum', 'bembidionilligeri', 'asaphidionpallipes', 'syntomustruncatellus', 'calodromiusspilotus', 'syntomusfoveatus', 'philorhizusmelanocephalus', 'calathusmelanocephalus', 'cicindelasylvatica', 'paradromiuslongiceps', 'paradromiuslinearis', 'calathusfuscipes', 'cicindelahybrida', 'blethisamultipunctata', 'cicindelacampestris', 'dyschiriusimpunctipennis', 'pogonuslittoralis', 'agonumthoreyi', 'agonummuelleri', 'dyschiriussalinus', 'dyschiriusobscurus', 'cychruscaraboides', 'notiophilusrufipes', 'agonumnigrum', 'poeciluscupreus', 'agonummarginatum', 'anchomenusdorsalis', 'oodeshelopioides', 'poecilusversicolor', 'poeciluslepidus', 'agonumfuliginosum', 'agonumversutum', 'agonummicans', 'laemostenusterricola', 'agonumgracile', 'agonumemarginatum', 'calathuserratus', 'agonumviduum', 'calathusambiguus', 'calathuscinctus', 'stenolophusskrimshiranus', 'polistichusconnexus', 'stenolophusmixtus', 'calathusmicropterus', 'bradycelluscaucasicus', 'calathusrotundicollis', 'stenolophusteutonus', 'bradycellusruficollis', 'ocysquinquestriatus', 'pogonuschalceus', 'bradycellussharpi', 'bradycellusverbasci', 'badistersodalis', 'badisterunipustulatus', 'badisterdilatatus', 'pogonusluridipennis', 'badisterbullatus', 'dromiusquadrimaculatus', 'dromiusangustus', 'demetriasimperialis', 'dyschiriustristis', 'dromiusmeridionalis', 'dromiusagilis', 'bembidionlitorale', 'bembidiontibiale', 'bembidionarticulatum', 'bembidionpunctulatum', 'bembidiongilvipes', 'demetriasatricapillus', 'ocysharpaloides', 'bembidionlunulatum', 'bembidionassimile', 'bembidiondecorum', 'carabusarcensis', 'chlaeniusvestitus', 'harpalusattenuatus', 'harpalusrufipalpis', 'calosomainquisitor', 'harpalusanxius', 'harpalusrubripes', 'dyschiriusglobosus', 'lebiachlorocephala', 'bembidionnigricorne', 'bembidionbipunctatum', 'bembidionmannerheimii', 'dyschiriuspolitus', 'bembidionatrocaeruleum', 'bembidionfluviatile', 'sinechostictusstomoides', 'bembidionfemoratum', 'bembidionvarium', 'harpaluslaevipes', 'notiophilusgerminyi', 'harpaluspumilus', 'harpalussmaragdinus', 'notiophilusquadripunctatus', 'cylinderagermanica', 'harpalusneglectus', 'chlaeniusnigricornis', 'harpalustardus', 'bembidionnormannum', 'pterostichusoblongopunctatus', 'pterostichusmadidus', 'pterostic ...
# ['platypleuracfcatenata', 'platypleurasp', 'platypleuraintercapedinis', 'platypleuraspcfhirtipennis', 'roeselianaroeselii', 'nemobiussylvestris', 'myopsaltamelanobasis', 'platypleuraintercapedinis', 'platypleuracfcatenata', 'tettigoniaviridissima', 'nemobiussylvestris', 'platypleuraplumosa', 'oecanthuspellucens', 'platypleurahirtipennis', 'chorthippusbrunneus', 'platypleuradivisa', 'pholidopteragriseoaptera', 'platypleurasp', 'platypleuracapensis', 'platypleuradeusta', 'grylluscampestris', 'platypleurasp', 'chorthippusbiguttulus', 'platypleurasp', 'platypleuracfcatenata', 'platypleurahirtipennis', 'platypleurasp', 'oecanthuspellucens', 'grylluscampestris', 'chorthippusbrunneus', 'tettigoniaviridissima', 'platypleurasp', 'roeselianaroeselii', 'platypleurahaglundi', 'platypleuraplumosa', 'platypleuraplumosa', 'platypleuraspcfhirtipennis', 'roeselianaroeselii', 'platypleuradeusta', 'myopsaltamackinlayi', 'azanicadazuluensis', 'pseudochorthippusparallelus', 'platypleurasp', 'platypleuraplumosa', 'kikihiamuta', 'myopsaltaleona', 'platypleuraspcfhirtipennis', 'platypleuradivisa', 'oecanthuspellucens', 'pseudochorthippusparallelus', 'kikihiamuta', 'grylluscampestris', 'myopsaltaxerograsidia', 'pycnasemiclara', 'pycnasemiclara', 'chorthippusbiguttulus', 'platypleurahaglundi', 'myopsaltalongicauda', 'myopsaltamackinlayi', 'grylluscampestris', 'pholidopteragriseoaptera', 'pholidopteragriseoaptera', 'tettigoniaviridissima', 'platypleurasp', 'platypleurachalybaea', 'myopsaltaleona', 'platypleurachalybaea', 'chorthippusbiguttulus', 'pseudochorthippusparallelus', 'nemobiussylvestris', 'myopsaltaxerograsidia', 'brevisianabrevis', 'platypleuracfcatenata', 'myopsaltamelanobasis']

# %%
#putting all bug species recordings into their own folders

#'''
#Storing the names and amount of each species in the dataset
path = "/content/SE/insectsound/"
csv = pd.read_csv("/content/SE/bugs.csv")

#move each species to own folder
bug_species = os.listdir(path) 
for bug in bug_species:
  raw_name = bug.partition("_")[0].lower()
  raw_name = ''.join(filter(lambda x: not x.isdigit(), raw_name)) #remove digits from name

  for index, row in csv.iterrows(): 
    species_name = row['species']
    blurred_name = species_name.lower().replace(" ", "")
    if blu

    filename = "xc" + str(row['id']) + ".flac"
    species[filename] = species_name




  bug_nl_list = pd.read_csv("/content/SE/bugs.csv")
unspaced_nl_species = []
for index, row in bug_nl_list.iterrows(): 
  country = row['nl']
  if country == "yes":
    species_name = row['species'].lower()
    species_name = species_name.replace(" ", "") #remove spaces from name
    unspaced_nl_species.append(species_name)
print (unspaced_nl_species)



  species = {}


  
    #print(bird, "is file")
    new_folder_name = species[bird] 
    new_folder = os.path.join(path, new_folder_name)
    new_path = os.path.join(new_folder, bird) 
    old_path = os.path.join(path, bird)
    #print(new_path)
    try:
      move = shutil.copy(old_path, new_path) 
    except:
      os.makedirs(new_folder) #messed up here at first so now theres just a map within every species but its fine
      move = shutil.copy(old_path, new_path) 
  else:
    #print(bird, "is folder")
    continue
 
#'''

# %% [markdown]
# # **NL Distributions**

# %% [markdown]
# ### Bird images    -  Finished

# %%
'''
#Storing the names and amount of each species in the dataset
path = "/content/SE/birds/train_nl/"
lst = os.listdir(path) 
nl_bird_diff_species = {}  #creating a dictionary
nl_bird_species_amount = len(lst) #might be with .ipynb checkpoints added so watch out!
print("number of bird species in the netherlands:", nl_bird_species_amount)

for nl_birds in lst:
  nl_bird_species_source = os.path.join(path, nl_birds)
  n_nl_birds_in_species = len(os.listdir(nl_bird_species_source))
  """print(nl_bird_species_source)"""
  nl_bird_diff_species.update({str(nl_birds): n_nl_birds_in_species})  #storing the species' names and how much of each there are in the data set

print(nl_bird_diff_species)

nl_bird_keys = nl_bird_diff_species.keys()
nl_bird_values = nl_bird_diff_species.values() '''

# %%
'''
#making a graph of all the species in the netherlands and how many there are of each in the dataset
#output is currently cleared to save room. See the shared Google Drive folder for the output
plt.figure(figsize=(10,10), dpi=200)

plt.barh(list(nl_bird_keys), nl_bird_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/birds/nl_bird_data_distribution.jpg") #name and path pf the output file
plt.show()
'''

#no need to run again as the file is already saved

# %% [markdown]
# ### Bird recordings  - Finished

# %%
#Storing the names and amount of each species in the dataset
path = "/content/SE/bird_recordings/flac_nl/"
lst = os.listdir(path) 
nl_bird_rec_diff_species = {}  #creating a dictionary
nl_bird_rec_species_amount = len(lst) #might be with .ipynb checkpoints added so watch out!
print("number of bird species in the netherlands:", nl_bird_rec_species_amount)

'''
for nl_birds_rec in lst:
  nl_bird_rec_species_source = os.path.join(path, nl_birds_rec)
  n_nl_birds_rec_in_species = len(os.listdir(nl_bird_rec_species_source))
  """print(nl_bird_rec_species_source)"""
  nl_bird_rec_diff_species.update({str(nl_birds_rec): n_nl_birds_rec_in_species})  #storing the species' names and how much of each there are in the data set

print(nl_bird_rec_diff_species)

nl_bird_rec_keys = nl_bird_rec_diff_species.keys()
nl_bird_rec_values = nl_bird_rec_diff_species.values()
'''

#gives same result
'''
for species in lst:
  species_path = os.path.join(path, species)
  species_amount = len(os.listdir(species_path))
  nl_bird_rec_diff_species[species] = species_amount
  
print(nl_bird_rec_diff_species)
'''
# Out:
# number of bird species in the netherlands: 56
# {'Common Redpoll': 2, 'Eurasian Sparrowhawk': 2, 'Long-tailed Tit': 11, 'Egyptian Goose': 10, 'Northern Shoveler': 1, 'Mallard': 2, 'Gadwall': 10, 'Meadow Pipit': 5, 'Tree Pipit': 8, 'Common Swift': 2, 'Ruddy Turnstone': 1, 'Long-eared Owl': 6, 'Common Pochard': 6, 'Tufted Duck': 9, 'Eurasian Bittern': 7, 'Brant Goose': 1, 'Canada Goose': 8, 'Barnacle Goose': 10, 'Red-breasted Goose': 1, 'White-throated Dipper': 10, 'Rock Dove': 6, 'Stock Dove': 5, 'Carrion Crow': 25, 'Tundra Swan': 9, 'Peregrine Falcon': 5, 'Eurasian Coot': 15, 'Common Moorhen': 1, 'Eurasian Jay': 9, 'Melodious Warbler': 8, 'Mediterranean Gull': 1, 'Eurasian Wryneck': 4, 'Lesser Black-backed Gull': 8, 'European Crested Tit': 4, 'Parrot Crossbill': 2, 'Woodlark': 3, 'Common Nightingale': 3, 'Smew': 2, 'White Wagtail': 1, 'Red-crested Pochard': 7, 'Northern Wheatear': 8, 'Great Cormorant': 7, 'Red-necked Phalarope': 9, 'Dusky Warbler': 9, "Hume's Leaf Warbler": 10, 'Yellow-browed Warbler': 8, "Pallas's Leaf Warbler": 10, 'Great Crested Grebe': 10, 'Willow Tit': 7, 'Spotted Crake': 8, "Baillon's Crake": 6, 'Rose-ringed Parakeet': 2, 'Common Eider': 1, 'Common Tern': 10, 'Little Tern': 2, 'Western Barn Owl': 10, 'Northern Lapwing': 2}

# %%
'''
#making a graph of all the species in the netherlands and how many there are of each in the dataset
#output is currently cleared to save room. See the shared Google Drive folder for the output
plt.figure(figsize=(5,10), dpi=200)

plt.barh(list(nl_bird_rec_keys), nl_bird_rec_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/bird_recordings/nl_bird_rec_data_distribution.jpg") #name and path pf the output file
plt.show()
'''

#no need to run again as the file is already saved

# %%
#testing against normal bird audio distribution to see if the amount of recordings per species is correct
#and rearranging folder for ease
'''
#Storing the names and amount of each species in the dataset
path = "/content/SE/bird_recordings/flac/"
csv = pd.read_csv("/content/SE/bird_recordings/xcmeta.csv", sep="\\t")

species = {}

for index, row in csv.iterrows(): 
  species_name = str(row['gen']) + " " + str(row['sp'])
  filename = "xc" + str(row['id']) + ".flac"
  species[filename] = species_name

#move each species to own folder
bird_rec = os.listdir(path) 
for bird in bird_rec:
  if ".flac" in bird: #if a file and not a folder
    #print(bird, "is file")
    new_folder_name = species[bird] 
    new_folder = os.path.join(path, new_folder_name)
    new_path = os.path.join(new_folder, bird) 
    old_path = os.path.join(path, bird)
    #print(new_path)
    try:
      move = shutil.move(old_path, new_path) 
    except:
      os.makedirs(new_folder) #messed up here at first so now theres just a map within every species but its fine
      move = shutil.move(old_path, new_path) 
  else:
    #print(bird, "is folder")
    continue

#making distribution
bird_rec_diff_species = {}  #creating a dictionary

for species in bird_rec:
  if ".flac" in species:
    continue
  else: #only use folders
    folder_path = os.path.join(path, species)
    bird_rec_species_amount = len(os.listdir(folder_path))
    bird_rec_diff_species[species] = bird_rec_species_amount  #storing the species' names and how much of each there are in the data set

print(bird_rec_diff_species)

bird_rec_keys = bird_rec_diff_species.keys()
bird_rec_values = bird_rec_diff_species.values()

plt.figure(figsize=(5,10), dpi=200)
plt.barh(list(bird_rec_keys), bird_rec_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/bird_recordings/bird_rec_data_distribution.jpg") #name and path pf the output file
plt.show()


#no need to run again as the file is already saved   
'''

#abort abort should move all files back.. messed up with a folder and the nl birds still dont show correctly
#do NOT run again
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)
# {'Locustella naevia': 28, 'Phylloscopus trochilus': 62, 'Loxia pytyopsittacus': 10, 'Motacilla aguimp': 10, 'Sylvia borin': 37, 'Ichthyaetus melanocephalus': 10, 'Turdus philomelos': 82, 'Acrocephalus scirpaceus': 23, 'Riparia riparia': 10, 'Sterna paradisaea': 10, 'Recurvirostra avosetta': 10, 'Tadorna tadorna': 10, 'Turdus pilaris': 14, 'Alauda arvensis': 27, 'Emberiza calandra': 54, 'Morus bassanus': 17, 'Parus major': 98, 'Motacilla flava': 32, 'Hirundo rustica': 46, 'Actitis hypoleucos': 29, 'Uria aalge': 10, 'Muscicapa striata': 20, 'Larus argentatus': 16, 'Fringilla coelebs': 194, 'Aegithalos caudatus': 29, 'Phylloscopus collybita': 86, 'Anser anser': 15, 'Columba livia': 10, 'Fregata minor': 10, 'Anous minutus': 9, 'Strix aluco': 35, 'Panurus biarmicus': 14, 'Dryocopus martius': 10, 'Caprimulgus europaeus': 11, 'Passer montanus': 157, 'Coloeus monedula': 20, 'Turdus iliacus': 17, 'Crex crex': 10, 'Chloephaga hybrida': 6, 'Pluvialis squatarola': 10, 'Tringa glareola': 10, 'Falco subbuteo': 10, 'Milvus milvus': 10, 'Picus viridis': 12, 'Diomedea exulans': 4, 'Tringa nebularia': 10, 'Anthus pratensis': 10, 'Asio otus': 10, 'Passer domesticus': 43, 'Sternula albifrons': 10, 'Thalasseus sandvicensis': 10, 'Anthus petrosus': 10, 'Prunella modularis': 50, 'Troglodytes troglodytes': 62, 'Anthus richardi': 10, 'Phylloscopus inornatus': 10, 'Calidris melanotos': 10, 'Jynx torquilla': 10, 'Motacilla citreola': 10, 'Asio flammeus': 10, 'Porzana pusilla': 10, 'Lagopus lagopus': 10, 'Turdus merula': 100, 'Acrocephalus schoenobaenus': 50, 'Egretta garzetta': 10, 'Columba palumbus': 21, 'Cygnus olor': 18, 'Sturnus vulgaris': 21, 'Streptopelia turtur': 10, 'Sylvia atricapilla': 47, 'Chroicocephalus ridibundus': 31, 'Accipiter nisus': 10, 'Larus marinus': 10, 'Luscinia svecica': 10, 'Sterna hirundo': 10, 'Falco tinnunculus': 10, 'Somateria spectabilis': 5, 'Motacilla cinerea': 10, 'Merops apiaster': 10, 'Erithacus rubecula': 58, 'Locustella fluviatilis': 10, 'Ficedula parva': 10, 'Grus grus': 10, 'Oriolus oriolus': 10, 'Hippolais polyglotta': 10, 'Larus fuscus': 10, 'Stercorarius parasiticus': 10, 'Fringilla montifringilla': 10, 'Aythya ferina': 10, 'Xema sabini': 3, 'Cepphus grylle': 3, 'Turdus torquatus': 10, 'Gallinago gallinago': 12, 'Mergus serrator': 10, 'Iduna pallida': 10, 'Phalacrocorax carbo': 10, 'Locustella luscinioides': 10, 'Cyanistes caeruleus': 76, 'Corvus frugilegus': 14, 'Emberiza schoeniclus': 10, 'Corvus corax': 10, 'Podiceps cristatus': 10, 'Regulus regulus': 19, 'Limosa limosa': 21, 'Scolopax rusticola': 10, 'Tringa ochropus': 10, 'Setophaga vitellina': 4, 'Tyrannus caudifasciatus': 10, 'Numenius tahitiensis': 10, 'Dendrocopos minor': 10, 'Arenaria interpres': 10, 'Sylvia communis': 46, 'Calidris alpina': 10, 'Botaurus stellaris': 10, 'Regulus ignicapilla': 10, 'Poecile montanus': 10, 'Vanellus vanellus': 11, 'Anas platyrhynchos': 10, 'Linaria cannabina': 19, 'Pyrrhula pyrrhula': 14, 'Carduelis carduelis': 23, 'Fulica atra': 20, 'Dendrocopos major': 40, 'Columba oenas': 10, 'Emberiza citrinella': 11, 'Turdus viscivorus': 32, 'Periparus ater': 29, 'Rallus aquaticus': 18, 'Buteo buteo': 11, 'Chloris chloris': 34, 'Streptopelia decaocto': 24, 'Branta leucopsis': 10, 'Oxyura jamaicensis': 10, 'Anas clypeata': 10, 'Loxia leucoptera': 10, 'Perdix perdix': 16, 'Phasianus colchicus': 17, 'Spheniscus magellanicus': 3, 'Aptenodytes patagonicus': 10, 'Phylloscopus humei': 10, 'Numenius arquata': 27, 'Acrocephalus arundinaceus': 10, 'Branta bernicla': 10, 'Sylvia curruca': 21, 'Carpodacus erythrinus': 10, 'Acrocephalus palustris': 22, 'Oenanthe oenanthe': 10, 'Phylloscopus bonelli': 10, 'Pica pica': 22, 'Branta canadensis': 15, 'Cettia cetti': 14, 'Tringa totanus': 21, 'Haematopus ostralegus': 18, 'Delichon urbicum': 33, 'Lullula arborea': 10, 'Cuculus canorus': 10, 'Serinus serinus': 10, 'Garrulus glandarius': 18, 'Coereba flaveola': 10, 'Acrocephalus dumetorum': 10, 'Motacilla alba': 10, 'Charadrius hiaticula': 10, 'Sylvia c ...

# %% [markdown]
# ### Bug Images  -  Finished

# %%
'''
#Storing the names and amount of each species in the dataset
path = "/content/SE/bug_img_nl/"
lst = os.listdir(path) 
nl_bug_diff_species = {}  #creating a dictionary
nl_bug_species_amount = len(lst) #might be with .ipynb checkpoints added so watch out!
print("number of bug species in the netherlands:", nl_bug_species_amount)

for nl_bugs in lst:
  nl_bug_species_source = os.path.join(path, nl_bugs)
  n_nl_bugs_in_species = len(os.listdir(nl_bug_species_source))
  """print(nl_bug_species_source)"""
  nl_bug_diff_species.update({str(nl_bugs): n_nl_bugs_in_species})  #storing the species' names and how much of each there are in the data set

print(nl_bug_diff_species)

nl_bug_keys = nl_bug_diff_species.keys()
nl_bug_values = nl_bug_diff_species.values() 
'''
# Out:
# number of bug species in the netherlands: 219
# {'Amara anthobia': 164, 'Nebria brevicollis': 475, 'Amara bifrons': 194, 'Amara apricaria': 221, 'Elaphrus riparius': 516, 'Bembidion bruxellense': 318, 'Bembidion guttula': 535, 'Bembidion quadrimaculatum': 269, 'Bembidion properans': 269, 'Asaphidion flavipes': 75, 'Clivina collaris': 212, 'Carabus granulatus': 246, 'Tachys scutellaris': 117, 'Clivina fossor': 472, 'Anisodactylus binotatus': 145, 'Acupalpus meridianus': 246, 'Bembidion ephippium': 181, 'Bembidion iricolor': 111, 'Dicheirotrichus gustavii': 362, 'Bembidion minimum': 368, 'Dicheirotrichus obsoletus': 151, 'Bembidion aeneum': 180, 'Bembidion fumigatum': 124, 'Broscus cephalotes': 403, 'Carabus monilis': 124, 'Panagaeus bipustulatus': 111, 'Carabus problematicus': 289, 'Amara lucida': 150, 'Amara similata': 223, 'Amara spreta': 119, 'Amara convexior': 170, 'Panagaeus cruxmajor': 52, 'Amara plebeja': 335, 'Amara eurynota': 115, 'Nebria salina': 208, 'Elaphrus cupreus': 333, 'Amara infima': 142, 'Zabrus tenebrioides': 63, 'Oxypselaphus obscurus': 410, 'Odacantha melanura': 107, 'Olisthopus rotundatus': 244, 'Synuchus vivalis': 111, 'Ophonus rupicola': 144, 'Anthracus consputus': 142, 'Trechus quadristriatus': 377, 'Trechoblemus micros': 127, 'Acupalpus exiguus': 144, 'Acupalpus brunnipes': 86, 'Patrobus atrorufus': 191, 'Syntomus foveatus': 280, 'Bembidion quadripustulatum': 65, 'Asaphidion pallipes': 210, 'Asaphidion curtum': 237, 'Calodromius spilotus': 204, 'Blemus discus': 53, 'Bembidion illigeri': 363, 'Syntomus truncatellus': 115, 'Cicindela campestris': 249, 'Calathus melanocephalus': 512, 'Cicindela hybrida': 65, 'Calathus fuscipes': 384, 'Cicindela sylvatica': 115, 'Blethisa multipunctata': 119, 'Paradromius linearis': 379, 'Philorhizus melanocephalus': 270, 'Agonum muelleri': 444, 'Dyschirius obscurus': 60, 'Dyschirius salinus': 234, 'Notiophilus rufipes': 196, 'Pogonus littoralis': 142, 'Dyschirius impunctipennis': 212, 'Cychrus caraboides': 190, 'Agonum thoreyi': 423, 'Poecilus cupreus': 325, 'Oodes helopioides': 112, 'Agonum marginatum': 375, 'Poecilus versicolor': 191, 'Poecilus lepidus': 113, 'Anchomenus dorsalis': 520, 'Agonum fuliginosum': 651, 'Agonum micans': 214, 'Agonum viduum': 184, 'Agonum emarginatum': 322, 'Agonum versutum': 57, 'Calathus ambiguus': 83, 'Laemostenus terricola': 156, 'Agonum gracile': 261, 'Calathus erratus': 214, 'Calathus rotundicollis': 203, 'Polistichus connexus': 61, 'Stenolophus mixtus': 289, 'Stenolophus skrimshiranus': 59, 'Bradycellus caucasicus': 113, 'Calathus cinctus': 170, 'Stenolophus teutonus': 128, 'Badister dilatatus': 69, 'Bradycellus verbasci': 329, 'Badister bullatus': 402, 'Bradycellus sharpi': 243, 'Pogonus luridipennis': 104, 'Bradycellus ruficollis': 327, 'Ocys quinquestriatus': 143, 'Badister sodalis': 134, 'Badister unipustulatus': 123, 'Pogonus chalceus': 384, 'Dromius angustus': 58, 'Dromius quadrimaculatus': 209, 'Dyschirius tristis': 217, 'Demetrias imperialis': 125, 'Dromius meridionalis': 168, 'Dromius agilis': 108, 'Bembidion tibiale': 316, 'Ocys harpaloides': 278, 'Bembidion decorum': 307, 'Bembidion gilvipes': 367, 'Bembidion litorale': 185, 'Bembidion lunulatum': 417, 'Demetrias atricapillus': 388, 'Bembidion articulatum': 458, 'Bembidion punctulatum': 381, 'Bembidion assimile': 243, 'Harpalus anxius': 335, 'Carabus arcensis': 134, 'Harpalus attenuatus': 119, 'Harpalus rubripes': 357, 'Harpalus rufipalpis': 208, 'Chlaenius vestitus': 166, 'Calosoma inquisitor': 114, 'Bembidion nigricorne': 113, 'Bembidion bipunctatum': 126, 'Lebia chlorocephala': 193, 'Dyschirius politus': 195, 'Bembidion mannerheimii': 275, 'Dyschirius globosus': 376, 'Bembidion atrocaeruleum': 426, 'Bembidion femoratum': 229, 'Bembidion fluviatile': 176, 'Bembidion varium': 450, 'Sinechostictus stomoides': 66, 'Notiophilus germinyi': 136, 'Cylindera germanica': 134, 'Notiophilus quadripunctatus': 71, 'Harpalus neglectus': 92, 'Bembidion normannum': 222, 'Harpalus smaragdinus': 116, 'Harpalus pumilus': 127, 'Chlaenius ni ...

# %%
'''
#making a graph of all the species in the netherlands and how many there are of each in the dataset
#output is currently cleared to save room. See the shared Google Drive folder for the output
plt.figure(figsize=(10,20), dpi=200)

plt.barh(list(nl_bug_keys), nl_bug_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/nl_bug_data_distribution.jpg") #name and path pf the output file
plt.show()


#no need to run again as the file is already saved   
'''

# %% [markdown]
# ### Bug recordings   -  Data Processing still needs to be preformed

# %%
#Storing the names and amount of each species in the dataset
path = "/content/SE/insectsound/ManualTrain"
lst = os.listdir(path) 

bug_diff_species = {}  #creating a dictionary
bug_species_amount = len(lst) 
print("number of bird species in the netherlands:", bug_species_amount)

for bug in lst:
  bug_species_source = os.path.join(path, bug)
  n_bug_in_species = len(os.listdir(bug_species_source))
  """print(nl_bird_species_source)"""
  bug_diff_species[bug] = n_bug_in_species  #storing the species' names and how much of each there are in the data set

print(bug_diff_species)

bug_keys = bug_diff_species.keys()
bug_values = bug_diff_species.values() 
#'''
# Out:
# number of bird species in the netherlands: 217
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-29-5062c9b6e04b> in <module>
#       9 for bug in lst:
#      10   bug_species_source = os.path.join(path, bug)
# ---> 11   n_bug_in_species = len(os.listdir(bug_species_source))
#      12   """print(nl_bird_species_source)"""
#      13   bug_diff_species[bug] = n_bug_in_species  #storing the species' names and how much of each there are in the data set
#
# NotADirectoryError: [Errno 20] Not a directory: '/content/SE/insectsound/ManualTrain/Pycnasemiclara_MHV%20925%20P.semiclara%20nr%20Grasskop%20%232.wav'

# %%
#'''
#making a graph of all the species in the netherlands and how many there are of each in the dataset
#output is currently cleared to save room. See the shared Google Drive folder for the output
plt.figure(figsize=(10,10), dpi=200)

plt.barh(list(nl_bird_keys), nl_bird_values, height=.8, align="center")
plt.yticks(fontsize=8)
plt.margins(y=0)

plt.tight_layout()

plt.savefig("/content/SE/birds/nl_bird_data_distribution.jpg") #name and path pf the output file
plt.show()
#'''

#no need to run again as the file is already saved

# %% [markdown]
# # To Do

# %%
- make distribution of bug_nl audio
- split bug image nl into train test val
- split bird audio nl into train test val

- turn wav into spectrograms

can we also do these by stratifying within train test?:
  - balance bug img dataset (we have data on distribution)
  - balance bug audio 
  - balance bird img dataset
  - balance bird audio (we have data on distribution)

# %%
#copy from location A to location B
#!cp /location/A/file /location/B/file

#move from location A to location B
#!mv /location/A/file /location/B/file

# %% [markdown]
# # **Model**

# %% [markdown]
# Importing stuff (again) to make sure the models work

# %%
#basic libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#for images
from sklearn.utils import shuffle
from sklearn.decomposition import PCA

#Model
from sklearn.neighbors import KNeighborsClassifier

#Model selection
from sklearn.model_selection import GridSearchCV

#evaluation metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score

# %% [markdown]
# Assigning Data for Birds

# %%
### Load the datasets
train_data = 
test_data = 

#Assign the train and test set
X_train = 
y_train =
X_test = 
y_test =

# %% [markdown]
# PCA on Bird Images

# %%
#Implementing PCA
n_components = 10    ###!NEEDS TO BE CHANGED!
pca = PCA(n_components=n_components).fit(X_train)
X_train_pca = pca.transform(X_train)
X_test_pca = pca.transform(X_test)

# Percentage of variance explained for the sum of each component
print('explained variance ratio with n_components =', n_components ,': %s' % str(sum(pca.explained_variance_ratio_)))

# %% [markdown]
# Creating a simple model for Bird Images

# %%
#Model creation and selection
param = {'n_neighbors':[1, 10, 100, 500]}

grid_search_knn = GridSearchCV(KNeighborsClassifier(), param_grid = param, cv=5)
grid_search_knn.fit(X_train_pca, y_train)

#Find the best hyperparameter
print("Best parameters: {}".format(grid_search_knn.best_params_))

# %% [markdown]
# Running the simple model for Bird Images

# %%
knn = KNeighborsClassifier(n_neighbors = 500).fit(X_train_pca, y_train)
y_pred_knn = knn.predict(X_test_pca)

# %% [markdown]
# Evaluating the simple model for Bird Images

# %%
#evaluation metrics
print("Accuracy: {:.3f}".format(accuracy_score(y_test, y_pred_knn)))
print("Confusion matrix:\n{}".format(confusion_matrix(y_test, y_pred_knn)))
print("Weighted f1-score:", f1_score(y_test, y_pred_knn, average='weighted'))
